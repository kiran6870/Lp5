# %%
# Library 
import tensorflow as tf 
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Flatten,Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Load Dataset 
(X_train,y_train),(X_test,y_test)=imdb.load_data(num_words=10000)

# %%
# padding 
X_train=pad_sequences(X_train,maxlen=200)
X_test=pad_sequences(X_test,maxlen=200)

# %%
# model 
model=Sequential()
model.add(Embedding(input_dim=10000,output_dim=32,input_length=200))
model.add(Flatten())
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# C:\ProgramData\anaconda3\envs\dsml37_env1\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X_train,y_train,epochs=5,batch_size=32)
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.7036 - loss: 0.5243
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9493 - loss: 0.1441
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9943 - loss: 0.0269
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9995 - loss: 0.0052
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 1.0000 - loss: 7.6462e-04

# %%
prediction=model.predict(X_test[:5])
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# [[0.00844163]
#  [0.9999872 ]
#  [0.95537037]
#  [0.06104101]
#  [0.99999386]]

# %%
y_pred_prob=model.predict(X_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
loss,acc=model.evaluate(X_test,y_test)
print("Accuracy:",acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8495 - loss: 0.6255
# Accuracy: 0.8488799929618835

# %%
y_pred=(y_pred_prob>0.5).astype(int)

# %%
for i in range(10):
    print(f"prob:{y_pred_prob[i][0]:.4f}|predictd:{y_pred[i][0]}|Actual:{y_test[i]}")
# Out:
# prob:0.0084|predictd:0|Actual:0
# prob:1.0000|predictd:1|Actual:1
# prob:0.9554|predictd:1|Actual:1
# prob:0.0610|predictd:0|Actual:0
# prob:1.0000|predictd:1|Actual:1
# prob:0.9077|predictd:1|Actual:1
# prob:0.6845|predictd:1|Actual:1
# prob:0.0000|predictd:0|Actual:0
# prob:0.9996|predictd:1|Actual:0
# prob:1.0000|predictd:1|Actual:1
